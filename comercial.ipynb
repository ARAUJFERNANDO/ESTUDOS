# %% [markdown]
# <a href="https://colab.research.google.com/github/ARAUJFERNANDO/ESTUDOS/blob/main/comercial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data = pd.read_excel ('/content/drive/MyDrive/ARQUIVOS/Gestão de Funil de Vendas-Padrao.xlsx')
data
# Out:
#       COD_CLIENTE                                       NOME_CLIENTE  \
# 0       025562-01  ABC MAQ - SERVICOS E COMERCIO LTDA            ...
# 1       011112-01  CONEXOES GERAIS COMERCIO E SERVICOS LTDA. EPP ...
# 2       A00618-01  R DOS SANTOS AQUECEDORES E MANUTENCAO         ...
# 3       A00618-01  R DOS SANTOS AQUECEDORES E MANUTENCAO         ...
# 4       A00618-01  R DOS SANTOS AQUECEDORES E MANUTENCAO         ...
# ...           ...                                                ...
# 69146   001909-01  HARKO ENGENHARIA LTDA                         ...
# 69147   019913-01  CLIMA CENTER MATERIAIS DE CONSTRUCAO LTDA - ME...
# 69148   019913-01  CLIMA CENTER MATERIAIS DE CONSTRUCAO LTDA - ME...
# 69149   021376-01  SOPECAS MAQUINAS NITEROI LTDA                 ...
# 69150   021376-01  SOPECAS MAQUINAS NITEROI LTDA                 ...
#
#                      CNPJ                                      VENDEDOR  \
# ...

# %%
data = pd.read_csv ('/content/sample_data/california_housing_test.csv')
data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [1,4,9,16,25]
plt.plot(x,y,color='blue')
plt.scatter(x,y,color='red')
plt.title('dados')
plt.ylabel('#Produtos')
plt.grid()
plt.legend (['estimativa','dado'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
